# %%
from email.policy import default
import mailbox
import email
import datetime
from datetime import datetime

# %% [markdown]
# # Data Cleaning

# %%
def replace_escape_characters(input_string):
    escape_characters = ["\\n", "\\t", "\\r", "\\b", "\\\\", "\\\"", "\\'", "\\f", "\\v", "\\a", '\"']
    
    for escape_char in escape_characters:
        input_string = input_string.replace(escape_char, "")
    
    return input_string.strip()

# %%
mbox_path = '/path/to/Unread.mbox'
mbox = mailbox.mbox(mbox_path, factory=lambda f: email.message_from_binary_file(f, policy=default))
 
email_data = []
for message in mbox:
    subject = message['subject']

    from_ = message['from'].replace(">", "").split("<")
    if len(from_) == 2:
        sender = replace_escape_characters(from_[0])
        email_sender = from_[1]
    else:
        if "@" in replace_escape_characters(from_[0]):
            sender = " "
            email_sender = replace_escape_characters(from_[0])
        else:
            sender = replace_escape_characters(from_[0])
            email_sender = " "

    email_receiver = "your mail"

    if "+" in message['date']:
        date = message['date'].split('+')[0].strip()
    elif "-" in message['date']:
        date = message['date'].split('-')[0].strip()
    extraction_date = datetime.strptime(date, '%a, %d %b %Y %H:%M:%S')

    if message.is_multipart():
        body = ""
        for part in message.walk():
            if part.get_content_type() == "text/plain":
                body += part.get_payload(decode=True).decode(part.get_content_charset())
    else:
        body = message.get_payload(decode=True).decode(message.get_content_charset())
    
    email_data.append((str(subject),sender,email_sender,"your name",str(email_receiver),extraction_date, body))

# %%
for i in email_data[1]:
    print(i)
    print("-"*50)
# Out:
# Congratulations on completing Communication Skills for University Success
# --------------------------------------------------
# Communication Skills for University Success
# --------------------------------------------------
# no-reply@t.mail.coursera.org
# --------------------------------------------------
# Trinh LeNhat
# --------------------------------------------------
# trinhlnde170294@fpt.edu.vn
# --------------------------------------------------
# 2022-12-27 09:03:16
# --------------------------------------------------
# Dear Trinh Le Nhat,
#
#
# Congratulations on finishing the course! Well done on all yourhard work and
# active participation on the course! Coursera will be in contactwith details
# on how to download your certificate.
#
#
# Also, don’t forget to take a look at the other MOOCs in this
# Specialization:
#
#
# Information & Digital Literacy for University Success
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvbGVhcm4vZGlnaXRhbC1saXRlcmFjeS9ob21lL3dlbGNvbWU_....GRKQ4Zq43QGzYkDAH7w1moOYOhwgy_n1bRcOeQJblkA>
#
#
# Problem-Solving Skills for University Success
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvbGVhcm4vcHJvYmxlbS1zb2x2aW5nLXNraWxscy9ob21lL3dlbGNvbWU_....6CjfFnlY5QQlJ9TB-IT0ls808baA8uZUvNijgGF2opQ>
#
#
# Critical Thinking Skills for University Success
# <https://eventing.coursera.-....T8UQl1-d6C80vJZkxSMAcsdKI95GrITmEebC2B0CMks>
#
#
# Capstone: Academic Skills for University Success
# <https://eventing.coursera.....y6GUheTbq0L7_SWyH_HjUYGIYXMSHorcsxCiFrTzTDQ>
#
#
# Once again, well done on finishing the course and we hope to see you on our
# other courses soon!
#
#
# Kind regards,
#
#
# Katherine Olston & Lydia Dutcher
#
#
# Communication Skills for University Success MOOC Instructors
#
#
# View completion
# <https://eventing.coursera.....rKd4Jse0p3sXGWZJZghiK0gRg707kesrBaFHfSSP6V4>
# [ Coursera ]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmc_....OcbG9R538QBmsZZjwXPpWhA2yappZKIhwBUjjYdZEZc>
# [facebook]
# <https://eventing.coursera.-....7u3ZruipHpkqEcjr3fyzV98Nv3PShso9OCjOjtpXZ98>
# [twitter]
# <https://eventing.coursera.....gmrQyXMsZuRjcKq8zbbt-A5u2LGeSHjZZbw-WPKPj14>
# [blog]
# <https://eventing.coursera.....zPN4xC6ywXLPjsIUeIVEaB1BFeoaGYnmcTkGtMTQIDo>
# [blog]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3BsdXMuZ29vZ2xlLmNvbS8xMTE5NTA1OTQwMzkyNjkyODE0NjkvcG9zdHM_....9GgdQi-SpvTS6aT0G33njJ0EpdcgwO7l-9y7n9PE4jw>
# You are receiving this email because trinhlnde170294@fpt.edu.vn is
# registered to the
# Communication Skills for University Success course at Coursera.
# Please do not reply directly to this email. If you have any questions or
# feedback,
# please visit our learner help center
# <https://eventing.coursera.-....xC-rPwtjaXotMusaxr-_mKMrK9rSzMDo1gQdwxbR7v8>
# .
# Copyright (c) 2022 Coursera, Inc | 381 E. Evelyn Avenue, Mountain View, CA
# 94041 USA
# unsubscribe from this list
# <https://eventing.coursera....-....Yc6EILDREUcp2Rp-r6-F713jY2GppNkbsYdq2cd1D08>
# --------------------------------------------------

# %% [markdown]
# # Create Dataframe using PySpark

# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
from pyspark.sql.functions import monotonically_increasing_id
from pyspark.sql.functions import lit

# %%
spark = SparkSession.builder \
    .appName("DataFrame") \
    .getOrCreate()

columns = ["subject","sender","email_sender","receiver","email_receiver","date", "content"]

rows = [Row(*row) for row in email_data]
rdd = spark.sparkContext.parallelize(rows)
df = spark.createDataFrame(rdd, columns)
df.show()
# Out:
# +--------------------+--------------------+--------------------+------------+--------------------+-------------------+--------------------+
# |             subject|              sender|        email_sender|    receiver|      email_receiver|               date|             content|
# +--------------------+--------------------+--------------------+------------+--------------------+-------------------+--------------------+
# |You have new or u...|            Coursera|no-reply@t.mail.c...|Trinh LeNhat|trinhlnde170294@f...|2024-04-03 15:15:20|You have received...|
# |Congratulations o...|Communication Ski...|no-reply@t.mail.c...|Trinh LeNhat|trinhlnde170294@f...|2022-12-27 09:03:16|Dear Trinh Le Nha...|
# |Get started with ...|            Coursera|no-reply@t.mail.c...|Trinh LeNhat|trinhlnde170294@f...|2024-03-20 17:59:39|[coursera logo]\r...|
# |Could You Be Part...|Artificial Intell...|no-reply@t.mail.c...|Trinh LeNhat|trinhlnde170294@f...|2023-11-20 16:01:15|Hi Trinh Le Nhat,...|
# |You're invited to...|FPT University + ...|no-reply@t.mail.c...|Trinh LeNhat|trinhlnde170294@f...|2024-01-10 08:38:34|Welcome to your l...|
# |Your invitation i...|     Phan Truong Lam|no-reply@t.mail.c...|Trinh LeNhat|trinhlnde170294@f...|2024-01-19 08:53:53|<https://eventing...|
# |The Secret to Eff...|Artificial Intell...|no-reply@t.mail.c...|Trinh LeNhat|trinhlnde170294@f...|2024-03-14 13:23:25|Hey Trinh Le Nhat...|
# |The Secret to Eff...|Artificial Intell...|no-reply@t.mail.c...|Trinh LeNhat|trinhlnde170294@f...|2024-03-14 13:22:07|Hey Trinh Le Nhat...|
# |Your invitation i...|     Phan Truong Lam|no-reply@t.mail.c...|Trinh LeNhat|trinhlnde170294@f...|2024-01-23 02:49:21|<https://eventing...|
# |You completed Wha...|            Coursera|no-reply@t.mail.c...|Trinh LeNhat|trinhlnde170294@f...|2023-11-03 03:23:15|Congratulations\r...|
# |Big Summer Sale |...|           Log2Base2|support@log2base2...|Trinh LeNhat|trinhlnde170294@f...|2023-05-31 13:17:38|<!DOCTYPE html> <...|
# |[Quiz to DN Heatw...|Luk danang Campus...|notifications+kwe...|Trinh LeNhat|trinhlnde170294@f...|2022-03-27 19:31:09|                    |
# |Verify your gover...|            Coursera|no-reply@t.mail.c...|Trinh LeNhat|trinhlnde170294@f...|2023-06-05 14:24:34|Verify your gover...|
# |Verify your gover...|            Coursera|no-reply@t.mail.c...|Trinh LeNhat|trinhlnde170294@f...|2023-06-05 13:44:57|Verify your gover...|
# | [RESFES_2024] V/...|          Lam Le Huu|    LamLH9@fe.edu.vn|Trinh LeNhat|trinhlnde170294@f...|2024-05-04 06:33:05|Dear bạn - trưởng...|
# |Enrol in 2-step v...|              Google|no-reply@accounts...|Trinh LeNhat|trinhlnde170294@f...|2023-05-23 01:43:10|[image: Google]\r...|
# |Congratulations o...|Information & Dig...|no-reply@t.mail.c...|Trinh LeNhat|trinhlnde170294@f...|2022-12-25 09:38:55|Dear Trinh Le Nha...|
# |Enrol in 2-step v...|              Google|no-reply@accounts...|Trinh LeNhat|trinhlnde170294@f...|2023-05-27 01:43:16|[image: Google]\r...|
# |Congratulations, ...|            Coursera|no-reply@t.mail.c...|Trinh LeNhat|trinhlnde170294@f...|2023-11-19 16:54:06|[ Welcome to Cour...|
# |Congratulations, ...|            Coursera|no-reply@t.mail.c...|Trinh LeNhat|trinhlnde170294@f...|2023-11-19 16:47:57|[ Welcome to Cour...|
# +--------------------+--------------------+--------------------+------------+--------------------+-------------------+--------------------+
# only showing top 20 rows

# %%
senders = df.select('sender', 'email_sender').distinct()

length = senders.count()

df_with_id = senders.withColumn("id_sender", lit(length) + monotonically_increasing_id())

senders = df_with_id.select("id_sender", *[col for col in df_with_id.columns if col != "id_sender"])

senders.show()
# Out:
# +---------+--------------------+--------------------+
# |id_sender|              sender|        email_sender|
# +---------+--------------------+--------------------+
# |       43|           Log2Base2|support@log2base2...|
# |       44|Artificial Intell...|no-reply@t.mail.c...|
# |       45|          Lam Le Huu|    LamLH9@fe.edu.vn|
# |       46|     Phan Truong Lam|no-reply@t.mail.c...|
# |       47|              Google|no-reply@accounts...|
# |       48|Artificial Intell...|no-reply@t.mail.c...|
# |       49|Communication Ski...|no-reply@t.mail.c...|
# |       50|Information & Dig...|no-reply@t.mail.c...|
# |       51|FPT University + ...|no-reply@t.mail.c...|
# |       52|            Coursera|no-reply@t.mail.c...|
# |       53|Luk danang Campus...|notifications+kwe...|
# |       54|                    |noreplyfptunivers...|
# |       55|                    |  it.fudn@fpt.edu.vn|
# |       56|          Vu Bui Cao|      vubc@fe.edu.vn|
# |       57|FPTStudentCareSystem| dvsv.fudn@fe.edu.vn|
# |       58|           Hoàng Sơn|  rtwf0311@gmail.com|
# |       59|Little UK Da Nang...|notifications+kwe...|
# |       60|Artificial Intell...|no-reply@t.mail.c...|
# |       61|              Edmodo|no-reply+kwer0kzf...|
# |       62|Luk hanoi Campus ...|notifications+kwe...|
# +---------+--------------------+--------------------+
# only showing top 20 rows

# %%
receivers = df.select('receiver', 'email_receiver').distinct()

length = receivers.count()

df_with_id = receivers.withColumn("id_receiver", lit(length) + monotonically_increasing_id())

receivers = df_with_id.select("id_receiver", *[col for col in df_with_id.columns if col != "id_receiver"])

receivers.show()
# Out:
# +-----------+------------+--------------------+
# |id_receiver|    receiver|      email_receiver|
# +-----------+------------+--------------------+
# |          1|Trinh LeNhat|trinhlnde170294@f...|
# +-----------+------------+--------------------+

# %%
infor_email = df.join(senders, (df['sender'] == senders['sender']) & (df["email_sender"] == senders['email_sender']), "inner")

infor_email = infor_email.join(receivers, (infor_email['receiver'] == receivers['receiver']) & (infor_email["email_receiver"] == receivers['email_receiver']), "inner")

infor_email = infor_email.select(
    infor_email['subject'],
    infor_email['id_sender'],
    receivers['id_receiver'],
    infor_email['date'],
    infor_email['content']
)

length = infor_email.count()
df_with_id = infor_email.withColumn("id_email", lit(length) + monotonically_increasing_id())
infor_email = df_with_id.select("id_email", *[col for col in df_with_id.columns if col != "id_email"])

infor_email.show()
# Out:
# +--------+--------------------+---------+-----------+-------------------+--------------------+
# |id_email|             subject|id_sender|id_receiver|               date|             content|
# +--------+--------------------+---------+-----------+-------------------+--------------------+
# |     331|Big Summer Sale |...|       43|          1|2023-05-31 13:17:38|<!DOCTYPE html> <...|
# |     332|Could You Be Part...|       44|          1|2023-11-20 16:01:15|Hi Trinh Le Nhat,...|
# |     333|The Secret to Eff...|       44|          1|2024-03-14 13:22:07|Hey Trinh Le Nhat...|
# |     334| [RESFES_2024] V/...|       45|          1|2024-05-04 06:33:05|Dear bạn - trưởng...|
# |     335|Your invitation i...|       46|          1|2024-01-19 08:53:53|<https://eventing...|
# |     336|Your invitation i...|       46|          1|2024-01-23 02:49:21|<https://eventing...|
# |     337|Enrol in 2-step v...|       47|          1|2023-05-23 01:43:10|[image: Google]\r...|
# |     338|Enrol in 2-step v...|       47|          1|2023-05-27 01:43:16|[image: Google]\r...|
# |     339|The Secret to Eff...|       48|          1|2024-03-14 13:23:25|Hey Trinh Le Nhat...|
# |     340|Congratulations o...|       49|          1|2022-12-27 09:03:16|Dear Trinh Le Nha...|
# |     341|Congratulations o...|       50|          1|2022-12-25 09:38:55|Dear Trinh Le Nha...|
# |     342|You're invited to...|       51|          1|2024-01-10 08:38:34|Welcome to your l...|
# |     343|You have new or u...|       52|          1|2024-04-03 15:15:20|You have received...|
# |     344|Get started with ...|       52|          1|2024-03-20 17:59:39|[coursera logo]\r...|
# |     345|You completed Wha...|       52|          1|2023-11-03 03:23:15|Congratulations\r...|
# |     346|Verify your gover...|       52|          1|2023-06-05 14:24:34|Verify your gover...|
# |     347|Verify your gover...|       52|          1|2023-06-05 13:44:57|Verify your gover...|
# |     348|Congratulations, ...|       52|          1|2023-11-19 16:54:06|[ Welcome to Cour...|
# |     349|Congratulations, ...|       52|          1|2023-11-19 16:47:57|[ Welcome to Cour...|
# |     350|[Quiz to DN Heatw...|       53|          1|2022-03-27 19:31:09|                    |
# +--------+--------------------+---------+-----------+-------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Insert to MySQL

# %%
import mysql.connector
from mysql.connector import Error

host = "127.0.0.1"
port = "3306"
db = "mail"
user = "user"
password = "password"
 
connection = mysql.connector.connect(
        host=host,
        database=db,
        user=user,
        password=password
    )

if connection.is_connected():
    cursor = connection.cursor()
    print("conneted")
# Out:
# conneted

# %%
try:
        create_senders_table = """
        CREATE TABLE IF NOT EXISTS senders (
            id_sender INT AUTO_INCREMENT PRIMARY KEY,
            sender VARCHAR(255) NOT NULL,
            email_sender VARCHAR(255) NOT NULL
        );
        """
        cursor.execute(create_senders_table)

        create_receivers_table = """
        CREATE TABLE IF NOT EXISTS receivers (
            id_receiver INT AUTO_INCREMENT PRIMARY KEY,
            receiver VARCHAR(255) NOT NULL,
            email_receiver VARCHAR(255) NOT NULL
        );
        """
        cursor.execute(create_receivers_table)

        create_emails_table = """
        CREATE TABLE IF NOT EXISTS emails (
            id_email INT AUTO_INCREMENT PRIMARY KEY,
            subject VARCHAR(255) NOT NULL,
            id_sender INT NOT NULL,
            id_receiver INT NOT NULL,
            date DATETIME NOT NULL,
            content TEXT NOT NULL,
            FOREIGN KEY (id_sender) REFERENCES senders(id_sender),
            FOREIGN KEY (id_receiver) REFERENCES receivers(id_receiver)
        );
        """ 
        cursor.execute(create_emails_table)
except Error as e:
    print(f"{e}")

# %%
for row in senders.collect():
    sql_query = """
                INSERT INTO senders (id_sender,sender, email_sender)
                VALUES (%s, %s, %s)
            """
    cursor.execute(sql_query, row)
        
connection.commit()
print("inserted data into senders")
# Out:
# inserted data into senders

# %%
for row in receivers.collect():
    sql_query = """
                INSERT INTO receivers (id_receiver,receiver,email_receiver)
                VALUES (%s, %s, %s)
            """
    cursor.execute(sql_query, row)
        
connection.commit()

print("inserted data into receivers")
# Out:
# inserted data into receivers

# %%
for row in infor_email.collect():
    sql_query = """
            INSERT INTO emails (id_email, subject, id_sender, id_receiver, date, content)
            VALUES (%s, %s, %s, %s, %s, %s)
        """
    cursor.execute(sql_query, row)
        
connection.commit()

print("inserted data into email")
# Out:
# inserted data into email

# %% [markdown]
# # Elasticsearch API

# %%
from elasticsearch import Elasticsearch

cloud_id = "cloud_id"
username = "username" 
password = "password" 
cloud_auth = (username, password)

es = Elasticsearch(cloud_id=cloud_id, basic_auth=cloud_auth)

# %%
import mysql.connector
mysql_conn = mysql.connector.connect(
    port = "3306",
    db = "mail",
    user = "user",
    password = "password"
)

# %%
cursor = mysql_conn.cursor()
cursor.execute("SELECT * FROM senders")
results = cursor.fetchall()

for row in results:
    doc = {
        'id': row[0],
        'sender': row[1],
        'email_sender': row[2],
    }
    es.index(index='senders',id=row[0], body=doc)

# %%
cursor = mysql_conn.cursor()
cursor.execute("SELECT * FROM receivers")
results = cursor.fetchall()

for row in results:
    doc = {
        'id': row[0],
        'receiver': row[1],
        'email_receiver': row[2],
    }
    es.index(index='receivers',id=row[0], body=doc)

# %%
cursor = mysql_conn.cursor()
cursor.execute("SELECT * FROM emails")
results = cursor.fetchall()

for row in results:
    doc = {
        'id_email': row[0],
        'subject': row[1],
        'id_sender': row[2],
        'id_receiver': row[3],
        'date': row[4],
        'content': row[5]
    }
    es.index(index='emails',id=row[0], body=doc)

# %%
row_ = input("row : ")
search_keyword = input("search_keyword : ")

search_results = es.search(index='emails', body={'query': {'match': {row_: search_keyword}}})

for hit in search_results['hits']['hits']:
    id_email = hit['_source']['id_email']
    query = f"""select e.id_email,e.subject,s.sender,s.email_sender,r.receiver,r.email_receiver,e.date,e.content
                from emails as e
                inner join receivers as r on e.id_receiver = r.id_receiver
                inner join senders as s on e.id_sender = s.id_sender 
                where e.id_email = {id_email}
                """
    cursor = mysql_conn.cursor()
    cursor.execute(query)
    results = cursor.fetchall()
    for i in results:
        for j in i:
            print(j)
            print("-"*20)
        print("+"*100)
# Out:
# 560
# --------------------
# Don't lose momentum!
# --------------------
# Coursera
# --------------------
# no-reply@t.mail.coursera.org
# --------------------
# Trinh LeNhat
# --------------------
# trinhlnde170294@fpt.edu.vn
# --------------------
# 2022-12-27 09:50:17
# --------------------
# [coursera logo]
#
#
# It only takes a few minutes
#
#
# Hi Trinh Le Nhat! Welcome to Academic Skills for University Success:
# Capstone. Your first lecture only takes 1 minutes.
#
# Welcome to the Academic Skills for University Success Specialization!
# Lecture • 1 min
# <https://eventing.coursera.-....i20wcZ7CnLmQyQkHMp999u23rf5NaGS09Wu3QJYH4EQ>
# Go to Lecture
# <https://eventing.coursera.-....i20wcZ7CnLmQyQkHMp999u23rf5NaGS09Wu3QJYH4EQ>
# Best of luck with your course,
# Kate from Coursera
# [name sig]
#
#
#
#
# Download our mobile app and learn on the go
#
#
# [iOS]
# <https://eventing.coursera.....VZt0kPif6PRJ7LOAP5Oo63j0JbuTSNfKgEKsKoFvCR8>
# [Android]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3BsYXkuZ29vZ2xlLmNvbS9zdG9yZS9hcHBzL2RldGFpbHM_....LmnYJUmqaZIKwyQMfMmr7IzTT3HUVVoZE6d_wk3cyyA>
#
#
#
#
# Connect with Coursera
# [FB]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL2ZhY2Vib29rLmNvbS9jb3Vyc2VyYT91dG1fbWVkaXVtPWVtYWlsJnV0bV9zb3VyY2U9b3RoZXImdXRtX2NhbXBhaWduPW9wZW5jb3Vyc2Uud2VsY29tZS5hY2FkZW1pYy1za2lsbHMtcHJvamVjdC5-....NVdc2rA9qFd0yAO1-Dn3aegxwipbGtG_ikfRLjRoZNo>
# [Twitter]
# <https://eventing.coursera.....5iIRzEFGogq36hqj79oJdQPJcSn0v5Lw-jRhI_Kbyis>
# [Linkedin]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5saW5rZWRpbi5jb20vY29tcGFueS9jb3Vyc2VyYT91dG1fbWVkaXVtPWVtYWlsJnV0bV9zb3VyY2U9b3RoZXImdXRtX2NhbXBhaWduPW9wZW5jb3Vyc2Uud2VsY29tZS5hY2FkZW1pYy1za2lsbHMtcHJvamVjdC5-....wXdkhsKAiL2g2DPAkQLgAan6nNjwcN0rnOaKZJHgUIM>
#
#
#
#
# Help
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL2xlYXJuZXIuY291cnNlcmEuaGVscD91dG1fbWVkaXVtPWVtYWlsJnV0bV9zb3VyY2U9b3RoZXImdXRtX2NhbXBhaWduPW9wZW5jb3Vyc2Uud2VsY29tZS5hY2FkZW1pYy1za2lsbHMtcHJvamVjdC5-....nHBHjXdR-1Tk18GFcZQrwIL7rQNqGY2knjIDCeUbNHw>
# |Coursera for Business
# <https://eventing.coursera.....8hSmP_fFza4H_RPFJen9l55igVdb4exbFSnKChYLiTY>
# |Email Settings
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvYWNjb3VudC1zZXR0aW5ncz91dG1fbWVkaXVtPWVtYWlsJnV0bV9zb3VyY2U9b3RoZXImdXRtX2NhbXBhaWduPW9wZW5jb3Vyc2Uud2VsY29tZS5hY2FkZW1pYy1za2lsbHMtcHJvamVjdC5-....IMonZa9SWJWNMfmzJwI1w-idYOBJ3ZrvhUf6TUekFAA>
# |Unsubscribe
# <https://eventing.coursera....-....7Dljgn8oXFVP6n8EpgrgwvBJgEMRKgsfcR6F83qkEvI>
#
#
#
#
# Copyright © 2022, Coursera Inc. | 381 E. Evelyn Ave, Mountain View, CA
# 94041 USA
# --------------------
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 585
# --------------------
# Don't lose momentum!
# --------------------
# Coursera
# --------------------
# no-reply@t.mail.coursera.org
# --------------------
# Trinh LeNhat
# --------------------
# trinhlnde170294@fpt.edu.vn
# --------------------
# 2022-12-24 06:01:48
# --------------------
# [coursera logo]
#
#
# It only takes a few minutes
#
#
# Hi Trinh Le Nhat! Welcome to Communication Skills for University Success.
# Your first lecture only takes 1 minutes.
#
# Welcome to the Academic Skills for University Success Specialization!
# Lecture • 1 min
# <https://eventing.coursera.-....mesUYaUBbsg8ZWwQDLBUtfySiXrTIQrYwAN7v9lWVFI>
# Go to Lecture
# <https://eventing.coursera.-....mesUYaUBbsg8ZWwQDLBUtfySiXrTIQrYwAN7v9lWVFI>
# Best of luck with your course,
# Kate from Coursera
# [name sig]
#
#
#
#
# Download our mobile app and learn on the go
#
#
# [iOS]
# <https://eventing.coursera.....mNVzHsj1A4fO6V5E0DnpcF3la4ArwUiDUmiLJh3kCkQ>
# [Android]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3BsYXkuZ29vZ2xlLmNvbS9zdG9yZS9hcHBzL2RldGFpbHM_....ovM3J2GfmppuEzgyitjpI16jpKd6Zd-SC68s1vmRuno>
#
#
#
#
# Connect with Coursera
# [FB]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL2ZhY2Vib29rLmNvbS9jb3Vyc2VyYT91dG1fbWVkaXVtPWVtYWlsJnV0bV9zb3VyY2U9b3RoZXImdXRtX2NhbXBhaWduPW9wZW5jb3Vyc2Uud2VsY29tZS5jb21tdW5pY2F0aW9uLXNraWxscy5-....hqo5nhw6oehVReDjeJzqTWNeRXy_kxoHRVBruJe09k0>
# [Twitter]
# <https://eventing.coursera.....K_-piqNXUOH2k-HdByp8Lmf_t5NXpTPv1OA4IXK98AY>
# [Linkedin]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5saW5rZWRpbi5jb20vY29tcGFueS9jb3Vyc2VyYT91dG1fbWVkaXVtPWVtYWlsJnV0bV9zb3VyY2U9b3RoZXImdXRtX2NhbXBhaWduPW9wZW5jb3Vyc2Uud2VsY29tZS5jb21tdW5pY2F0aW9uLXNraWxscy5-...._o-3wiIwbx1OBZAZNtr2IdC-lFgAqIhT_1bxx9LY0ds>
#
#
#
#
# Help
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL2xlYXJuZXIuY291cnNlcmEuaGVscD91dG1fbWVkaXVtPWVtYWlsJnV0bV9zb3VyY2U9b3RoZXImdXRtX2NhbXBhaWduPW9wZW5jb3Vyc2Uud2VsY29tZS5jb21tdW5pY2F0aW9uLXNraWxscy5-....iSfyI49ErLz-utTYuI03siDE5nCY9XomUewyeEy2EHI>
# |Coursera for Business
# <https://eventing.coursera.....jxlITNT_80FkfompIfYHXBISkTOHt0mfnc200med8Uk>
# |Email Settings
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvYWNjb3VudC1zZXR0aW5ncz91dG1fbWVkaXVtPWVtYWlsJnV0bV9zb3VyY2U9b3RoZXImdXRtX2NhbXBhaWduPW9wZW5jb3Vyc2Uud2VsY29tZS5jb21tdW5pY2F0aW9uLXNraWxscy5-....z-kHDb3Ki7G-P6f2-Eam30Ip8kEOM-N_emc3al1lmy8>
# |Unsubscribe
# <https://eventing.coursera....-....y54iiwe2E12AjpHXbLO9cklwG_Ht5swRASbPea-kihg>
#
#
#
#
# Copyright © 2022, Coursera Inc. | 381 E. Evelyn Ave, Mountain View, CA
# 94041 USA
# --------------------
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 627
# --------------------
# Don't lose momentum!
# --------------------
# Coursera
# --------------------
# no-reply@t.mail.coursera.org
# --------------------
# Trinh LeNhat
# --------------------
# trinhlnde170294@fpt.edu.vn
# --------------------
# 2022-11-30 14:32:13
# --------------------
# [coursera logo]
#
#
# It only takes a few minutes
#
#
# Hi Trinh Le Nhat! Welcome to Critical Thinking Skills for University
# Success. Your first lecture only takes 1 minutes.
#
# Welcome to the Academic Skills for University Success Specialization!
# Lecture • 1 min
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvbGVhcm4vY3JpdGljYWwtdGhpbmtpbmctc2tpbGxzL2l0ZW0vT1RjQVo_....9IuvzWK3D6SMjUTY67EyGivvBiBrmv00YfdYSBYD64g>
# Go to Lecture
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvbGVhcm4vY3JpdGljYWwtdGhpbmtpbmctc2tpbGxzL2l0ZW0vT1RjQVo_....9IuvzWK3D6SMjUTY67EyGivvBiBrmv00YfdYSBYD64g>
# Best of luck with your course,
# Kate from Coursera
# [name sig]
#
#
#
#
# Download our mobile app and learn on the go
#
#
# [iOS]
# <https://eventing.coursera.-....B_ukT34ywBh4CstnVpaNOPvXsL5dUCpJ6nQDjf0WPtg>
# [Android]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3BsYXkuZ29vZ2xlLmNvbS9zdG9yZS9hcHBzL2RldGFpbHM_....Zu44bhi-Dh78q31hT0SrJUkNx7aW0HcSo00su-Unkac>
#
#
#
#
# Connect with Coursera
# [FB]
# <https://eventing.coursera.....MGDACa3JRS1BaQwVh3k9ir1DjFM-Z0uZyeZyrcq7Y-Q>
# [Twitter]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3R3aXR0ZXIuY29tL2NvdXJzZXJhP3V0bV9tZWRpdW09ZW1haWwmdXRtX3NvdXJjZT1vdGhlciZ1dG1fY2FtcGFpZ249b3BlbmNvdXJzZS53ZWxjb21lLmNyaXRpY2FsLXRoaW5raW5nLXNraWxscy5-....ZAzih7bCVtYcTA9kgoVRBs5lVl0gBKPAPa8-vcoFb50>
# [Linkedin]
# <https://eventing.coursera.....GNdqWB3G3Ur9l66oBzIZTRTjYObiTMA3fB9tNj33HRg>
#
#
#
#
# Help
# <https://eventing.coursera.....IO3M2mILunY7c7wMDKIRfWnWfSnMK1lzmzCZbyC_Qcc>
# |Coursera for Business
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvYnVzaW5lc3MvP3V0bV9tZWRpdW09ZW1haWwmdXRtX3NvdXJjZT1vdGhlciZ1dG1fY2FtcGFpZ249b3BlbmNvdXJzZS53ZWxjb21lLmNyaXRpY2FsLXRoaW5raW5nLXNraWxscy5-....UEuVuKWKSNtdPE46JH3bEqoOYeBDK5Hkd2F60RD1Q7Q>
# |Email Settings
# <https://eventing.coursera.....vhrsrvyoMoEIDsASPkgdMsXPlSaJ291wAQKsYzRJ1hM>
# |Unsubscribe
# <https://eventing.coursera.....Fjj7ZIVgLcZtiecBketruiA9dOj-aGaU2Joon28rT0c>
#
#
#
#
# Copyright © 2022, Coursera Inc. | 381 E. Evelyn Ave, Mountain View, CA
# 94041 USA
# --------------------
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 504
# --------------------
# Get started with your first lecture
# --------------------
# Coursera
# --------------------
# no-reply@t.mail.coursera.org
# --------------------
# Trinh LeNhat
# --------------------
# trinhlnde170294@fpt.edu.vn
# --------------------
# 2023-11-19 16:33:10
# --------------------
# [coursera logo]
#
#
# You're on your way to new skills
#
#
# Hi Trinh Le Nhat,
#
# Welcome to Artificial Intelligence Privacy and Convenience. Start learning
# with your first lecture, which only takes 3 minutes. You're on your way to
# new skills!
#
# Course Introduction
# Lecture • 3 min
# <https://eventing.coursera.-....6toemB4vb524WT7fO4yQkNm-tPxgC7yrOVX2WnQvJCI>
# Go to Lecture
# <https://eventing.coursera.-....6toemB4vb524WT7fO4yQkNm-tPxgC7yrOVX2WnQvJCI>
# Happy Learning,
# Coursera
#
# Looking for other tips to boost learning success?
#     * Download our mobile app
#       <https://eventing.coursera.....ee6SeomW9VyBUxA7ezYbstyTf7oCEdcrCI86hh9JkTQ>
#       to keep making progress anywhere
#     * Use the calendar feature
#       <https://eventing.coursera.-....L8rD4hbDayu0xrBAF7RR1zpztwMqAS88EGVwIGMII_0>
#       to schedule time for learning
#     * Adopt one or two study habits
#       <https://eventing.coursera.....L5HsVGReZslH81EaVOwD50XkzLegV5OPwehusd3TF2o>
#       that make learning work for you
#
#
#
#
# Download our mobile app and learn on the go
#
#
# [iOS]
# <https://eventing.coursera.....xZ4nZ0Klq8Mw_Ko6uaJiCBjfrrJmw3nb4W6H77BzCW8>
# [Android]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3BsYXkuZ29vZ2xlLmNvbS9zdG9yZS9hcHBzL2RldGFpbHM_....r6Y9Bf46e9YuViRlSrOO87iPb-IRntmoe4fkxEwY0mc>
#
#
#
#
# Connect with Coursera
# [FB]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL2ZhY2Vib29rLmNvbS9jb3Vyc2VyYT91dG1fbWVkaXVtPWVtYWlsJnV0bV9zb3VyY2U9b3RoZXImdXRtX2NhbXBhaWduPW9wZW5jb3Vyc2Uud2VsY29tZS5haS1wcml2YWN5LWFuZC1jb252ZW5pZW5jZS5-....g1D3AK4Uju0AFEc2lv-HMYNDwizNyw_eHqviIXNHO0g>
# [Twitter]
# <https://eventing.coursera.....dKHMNnteCHNMC1vkLggDcsJ9tTraLLSJgbWr4CtcBW4>
# [Linkedin]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5saW5rZWRpbi5jb20vY29tcGFueS9jb3Vyc2VyYT91dG1fbWVkaXVtPWVtYWlsJnV0bV9zb3VyY2U9b3RoZXImdXRtX2NhbXBhaWduPW9wZW5jb3Vyc2Uud2VsY29tZS5haS1wcml2YWN5LWFuZC1jb252ZW5pZW5jZS5-....BxyKJqkFDyp_bbblubH6eGh-k_rl6Ak_QFKnyZjAPfI>
#
#
#
#
# Help
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL2xlYXJuZXIuY291cnNlcmEuaGVscD91dG1fbWVkaXVtPWVtYWlsJnV0bV9zb3VyY2U9b3RoZXImdXRtX2NhbXBhaWduPW9wZW5jb3Vyc2Uud2VsY29tZS5haS1wcml2YWN5LWFuZC1jb252ZW5pZW5jZS5-....acKFhzJXmaJchJvyP15zse8AUx7GKl2Nd5x1Yj6bCLA>
# |Coursera for Business
# <https://eventing.coursera.....8y9JPrQB7RiTSsVhwXkclU8ALLnGxtIthYSRa9MVEJw>
# |Email Settings
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvYWNjb3VudC1zZXR0aW5ncz91dG1fbWVkaXVtPWVtYWlsJnV0bV9zb3VyY2U9b3RoZXImdXRtX2NhbXBhaWduPW9wZW5jb3Vyc2Uud2VsY29tZS5haS1wcml2YWN5LWFuZC1jb252ZW5pZW5jZS5-....ZYvefLbHT9bDUbhn8bq33A26RqO0RrdM_Cs4MMeBfOs>
# |Unsubscribe
# <https://eventing.coursera....-....wEs2JbpalS-MfJd0xZbb_AIJFiNq81EfEb3hNg0ug9E>
#
#
#
#
# Copyright © 2023, Coursera Inc. | 381 E. Evelyn Ave, Mountain View, CA
# 94041 USA
# --------------------
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 505
# --------------------
# Get started with your first lecture
# --------------------
# Coursera
# --------------------
# no-reply@t.mail.coursera.org
# --------------------
# Trinh LeNhat
# --------------------
# trinhlnde170294@fpt.edu.vn
# --------------------
# 2023-11-19 16:21:17
# --------------------
# [coursera logo]
#
#
# You're on your way to new skills
#
#
# Hi Trinh Le Nhat,
#
# Welcome to Artificial Intelligence Data Fairness and Bias . Start learning
# with your first lecture, which only takes 2 minutes. You're on your way to
# new skills!
#
# Course Introduction Video
# Lecture • 2 min
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvbGVhcm4vYWktZGF0YS1iaWFzL2l0ZW0vb0hsWFc_....E_uIka88f2bwFH7MQwvmIgKkn69ziQp4k1geYOLCpZI>
# Go to Lecture
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvbGVhcm4vYWktZGF0YS1iaWFzL2l0ZW0vb0hsWFc_....E_uIka88f2bwFH7MQwvmIgKkn69ziQp4k1geYOLCpZI>
# Happy Learning,
# Coursera
#
# Looking for other tips to boost learning success?
#     * Download our mobile app
#       <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvYWJvdXQvbW9iaWxlP3V0bV9tZWRpdW09ZW1haWwmdXRtX3NvdXJjZT1vdGhlciZ1dG1fY2FtcGFpZ249b3BlbmNvdXJzZS53ZWxjb21lLmFpLWRhdGEtYmlhcy5-....NilfAKZi9I4U4aDBuyno1UbnY9JRkfL-u1N8V4KPDJc>
#       to keep making progress anywhere
#     * Use the calendar feature
#       <https://eventing.coursera.....i-Rp2i8kDuc4S1BngliX77wzs04ioJt02kds3r1AQ9c>
#       to schedule time for learning
#     * Adopt one or two study habits
#       <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvYXJ0aWNsZXMvc3R1ZHktaGFiaXRzP3V0bV9tZWRpdW09ZW1haWwmdXRtX3NvdXJjZT1vdGhlciZ1dG1fY2FtcGFpZ249b3BlbmNvdXJzZS53ZWxjb21lLmFpLWRhdGEtYmlhcy5-....wIrlj4NVbbZZk21rkbTzkcwpoXm_OPYkQwgJ6pKW6DU>
#       that make learning work for you
#
#
#
#
# Download our mobile app and learn on the go
#
#
# [iOS]
# <https://eventing.coursera.-....aOWq3xRYTIt-B4IsECzqTiygSNTiQ8x3z9JjnFBx7rc>
# [Android]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3BsYXkuZ29vZ2xlLmNvbS9zdG9yZS9hcHBzL2RldGFpbHM_....GgE_4VFo7_aMnIuq4zqtvuKqWcr629mojCoB_gQyGm0>
#
#
#
#
# Connect with Coursera
# [FB]
# <https://eventing.coursera.....pLLm0cURlu8AhSRShVMhjBLFUmMF7DDSySeDjb79JmA>
# [Twitter]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3R3aXR0ZXIuY29tL2NvdXJzZXJhP3V0bV9tZWRpdW09ZW1haWwmdXRtX3NvdXJjZT1vdGhlciZ1dG1fY2FtcGFpZ249b3BlbmNvdXJzZS53ZWxjb21lLmFpLWRhdGEtYmlhcy5-....qhsevXCOSHVGbJjAmTUbdWenCMroaHoSsKF2zQurUZ8>
# [Linkedin]
# <https://eventing.coursera.....zTvtzwtDOV70HQfZAlyRKpvkcb4HPj4Wsps-sgIG6Ds>
#
#
#
#
# Help
# <https://eventing.coursera.....rCAxGHZ9j76pRrE7_OEatteHIQlTwxs3kvViW5WUJsE>
# |Coursera for Business
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvYnVzaW5lc3MvP3V0bV9tZWRpdW09ZW1haWwmdXRtX3NvdXJjZT1vdGhlciZ1dG1fY2FtcGFpZ249b3BlbmNvdXJzZS53ZWxjb21lLmFpLWRhdGEtYmlhcy5-....evjeIOpHb9qkQNT2LJCPvYY7AiM7m6VM2wvABsgIEVE>
# |Email Settings
# <https://eventing.coursera.....OHxLaikfQc9hxoVWQLOVz2cZ_dFvofikza5Fntnd7mk>
# |Unsubscribe
# <https://eventing.coursera.....BsY7tQLp1AVLkbucUMOH2btfuKgFLUXle-1ghDgZrZs>
#
#
#
#
# Copyright © 2023, Coursera Inc. | 381 E. Evelyn Ave, Mountain View, CA
# 94041 USA
# --------------------
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 566
# --------------------
# Get started with your first lecture
# --------------------
# Coursera
# --------------------
# no-reply@t.mail.coursera.org
# --------------------
# Trinh LeNhat
# --------------------
# trinhlnde170294@fpt.edu.vn
# --------------------
# 2024-03-20 17:59:18
# --------------------
# [coursera logo]
#
#
# You're on your way to new skills
#
#
# Hi Trinh Le Nhat,
#
# Welcome to Lean Software Development. Start learning with your first
# lecture, which only takes 2 minutes. You're on your way to new skills!
#
# Welcome and Course Intro
# Lecture • 2 min
# <https://eventing.coursera.....2myIcEyA8NjOnhb4Y_lbvnD9eIuWaOaqfnntwjVy2nw>
# Go to Lecture
# <https://eventing.coursera.....2myIcEyA8NjOnhb4Y_lbvnD9eIuWaOaqfnntwjVy2nw>
# Happy Learning,
# Coursera
#
# Looking for other tips to boost learning success?
#     * Download our mobile app
#       <https://eventing.coursera.....dW-krwGSEcauxxSm4x2L6xL0o0bD-7CUcgLrgH4JpTA>
#       to keep making progress anywhere
#     * Use the calendar feature
#       <https://eventing.coursera.....BllweLsadg2vvC8CSBOXfr12rdzgWigG4c1-L-zFiDQ>
#       to schedule time for learning
#     * Adopt one or two study habits
#       <https://eventing.coursera.....gCY-fIaMwI0ppGeY5NpuPT2OHylrHrhFrHit0rWSTQI>
#       that make learning work for you
#
#
#
#
# Download our mobile app and learn on the go
#
#
# [iOS]
# <https://eventing.coursera.....HgjjkPgxyN7-g5mmVezlvhK1T1vzlB9TV1rjMnRjCoc>
# [Android]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3BsYXkuZ29vZ2xlLmNvbS9zdG9yZS9hcHBzL2RldGFpbHM_aWQ9b3JnLmNvdXJzZXJhLmFuZHJvaWQmdXRtX21lZGl1bT1lbWFpbCZ1dG1fc291cmNlPW90aGVyJnV0bV9jYW1wYWlnbj1vcGVuY291cnNlLndlbGNvbWUubGVhbi1zb2Z0d2FyZS1kZXZlbG9wbWVudC5-....FdHQ2dMRRQxAn9HtvF7Ac7fGkPgXwgK7Vr28rMc9jp8>
#
#
#
#
# Connect with Coursera
# [FB]
# <https://eventing.coursera.....NMShOqbhhS3gCWzTx5a_AE762BlKUgEMTA3OApsw7hw>
# [Twitter]
# <https://eventing.coursera.....rZapfG9iKo1mbJrPUPman7koX_I95ATa4kFrYGJCIWA>
# [Linkedin]
# <https://eventing.coursera.....8Hgdl9xEaxS8B3Ww2OZhgZe3wpsK1LaX1xspTajt3mc>
#
#
#
#
# Help
# <https://eventing.coursera.....dhrrCgyPU2bm_TI8TY9QJDtUyilxl4SznWwvJEEVxWc>
# |Coursera for Business
# <https://eventing.coursera.....5s5pxsb4Tcm1UwQPKkaahYjRCog08Xt51lUDRBLxMQ8>
# |Email Settings
# <https://eventing.coursera.....Z6Ur_nyUZEg1iYTpU0Dj2n1oRLTDqxq7RDXLuLlb6Zk>
# |Unsubscribe
# <https://eventing.coursera.....y4mX3-RxQuS6I3LR-e2Ni8r5_w_pzr9TTK8b4Qp6Pio>
#
#
#
#
# Copyright © 2024, Coursera Inc. | 381 E. Evelyn Ave, Mountain View, CA
# 94041 USA
# --------------------
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 568
# --------------------
# Get started with your first lecture
# --------------------
# Coursera
# --------------------
# no-reply@t.mail.coursera.org
# --------------------
# Trinh LeNhat
# --------------------
# trinhlnde170294@fpt.edu.vn
# --------------------
# 2024-03-20 17:58:03
# --------------------
# [coursera logo]
#
#
# You're on your way to new skills
#
#
# Hi Trinh Le Nhat,
#
# Welcome to Software Development Processes and Methodologies. Start learning
# with your first lecture, which only takes 3 minutes. You're on your way to
# new skills!
#
# Why Take This Course?
# Lecture • 3 min
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvbGVhcm4vc29mdHdhcmUtcHJvY2Vzc2VzL2l0ZW0vM1RJM1I_....c5jeAErgDKxhnNkv_QDGooDVhaW5xiaC_VdJFH6yH2w>
# Go to Lecture
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvbGVhcm4vc29mdHdhcmUtcHJvY2Vzc2VzL2l0ZW0vM1RJM1I_....c5jeAErgDKxhnNkv_QDGooDVhaW5xiaC_VdJFH6yH2w>
# Happy Learning,
# Coursera
#
# Looking for other tips to boost learning success?
#     * Download our mobile app
#       <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvYWJvdXQvbW9iaWxlP3V0bV9tZWRpdW09ZW1haWwmdXRtX3NvdXJjZT1vdGhlciZ1dG1fY2FtcGFpZ249b3BlbmNvdXJzZS53ZWxjb21lLnNvZnR3YXJlLXByb2Nlc3Nlcy5-....koPtqfvdwbFcynvVX1_6JVxEITuGCaeDkHq1eQNnQuM>
#       to keep making progress anywhere
#     * Use the calendar feature
#       <https://eventing.coursera.....4N3zAiak2bhkd6X82_ChsTFj0bZLGfrCXsHI5rqzJ5Q>
#       to schedule time for learning
#     * Adopt one or two study habits
#       <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvYXJ0aWNsZXMvc3R1ZHktaGFiaXRzP3V0bV9tZWRpdW09ZW1haWwmdXRtX3NvdXJjZT1vdGhlciZ1dG1fY2FtcGFpZ249b3BlbmNvdXJzZS53ZWxjb21lLnNvZnR3YXJlLXByb2Nlc3Nlcy5-....MEHPj-yv48lKCIBE_YJ_OMy3c2yQdCtR5QGZZCguQ8s>
#       that make learning work for you
#
#
#
#
# Download our mobile app and learn on the go
#
#
# [iOS]
# <https://eventing.coursera.-....lvrpX51dGMDa6wKxeDG4SLlWhfIfURQm8Z3nk9a6a7k>
# [Android]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3BsYXkuZ29vZ2xlLmNvbS9zdG9yZS9hcHBzL2RldGFpbHM_....eBdaxctcmZ97Xr9oxOp6ZXKMdZwzphQIE_FUf4oqKws>
#
#
#
#
# Connect with Coursera
# [FB]
# <https://eventing.coursera.....5wBi-GfIKb78c7FCUmMThYjYrVJqIBx9vxs1gr4aSR0>
# [Twitter]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3R3aXR0ZXIuY29tL2NvdXJzZXJhP3V0bV9tZWRpdW09ZW1haWwmdXRtX3NvdXJjZT1vdGhlciZ1dG1fY2FtcGFpZ249b3BlbmNvdXJzZS53ZWxjb21lLnNvZnR3YXJlLXByb2Nlc3Nlcy5-....QZZgiQUbM1y-l-50vicposd86OkSx0QIvRU6CZcOUt4>
# [Linkedin]
# <https://eventing.coursera.....-gHbkRsHKP21zzesFfYL_0mC113w9J0WsaiXm1u6j5o>
#
#
#
#
# Help
# <https://eventing.coursera.....mhGMb8zJmN5iXCa1QSWq6k5oojCxADj4Tsd-w5tlEJo>
# |Coursera for Business
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvYnVzaW5lc3MvP3V0bV9tZWRpdW09ZW1haWwmdXRtX3NvdXJjZT1vdGhlciZ1dG1fY2FtcGFpZ249b3BlbmNvdXJzZS53ZWxjb21lLnNvZnR3YXJlLXByb2Nlc3Nlcy5-....-1pGiEemrEmkr5hAc_vSd_aKjOxwulu24N4jUxBREkA>
# |Email Settings
# <https://eventing.coursera.....w_dcyTMm4tmBrw-e4Id5EKu8QqEIJ5aPOfGeaSVIPHU>
# |Unsubscribe
# <https://eventing.coursera.....yPPZhUx8mjgz7-z5chpI8dLp89HszDyfljIh58Rc54I>
#
#
#
#
# Copyright © 2024, Coursera Inc. | 381 E. Evelyn Ave, Mountain View, CA
# 94041 USA
# --------------------
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 577
# --------------------
# Get started with your first supplement
# --------------------
# Coursera
# --------------------
# no-reply@t.mail.coursera.org
# --------------------
# Trinh LeNhat
# --------------------
# trinhlnde170294@fpt.edu.vn
# --------------------
# 2023-11-03 14:06:24
# --------------------
# [coursera logo]
#
#
# You're on your way to new skills
#
#
# Hi Trinh Le Nhat,
#
# Welcome to Data Science Methodology. Start learning with your first
# reading, which only takes 10 minutes. You're on your way to new skills!
#
# Welcome
# Reading • 10 min
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvbGVhcm4vZGF0YS1zY2llbmNlLW1ldGhvZG9sb2d5L2l0ZW0vbVBOVzA_....6CD19WS973D32BY_2v8qjDOd3c3C8bJqRm9C2Idk5Gw>
# Go to Reading
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvbGVhcm4vZGF0YS1zY2llbmNlLW1ldGhvZG9sb2d5L2l0ZW0vbVBOVzA_....6CD19WS973D32BY_2v8qjDOd3c3C8bJqRm9C2Idk5Gw>
# Happy Learning,
# Coursera
#
# Looking for other tips to boost learning success?
#     * Download our mobile app
#       <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvYWJvdXQvbW9iaWxlP3V0bV9tZWRpdW09ZW1haWwmdXRtX3NvdXJjZT1vdGhlciZ1dG1fY2FtcGFpZ249b3BlbmNvdXJzZS53ZWxjb21lLmRhdGEtc2NpZW5jZS1tZXRob2RvbG9neS5-....awHcJ8TtkmaDCzBD1YVz99bIZQbaGjO8QWl4EqPgq_Y>
#       to keep making progress anywhere
#     * Use the calendar feature
#       <https://eventing.coursera.....K1auK1ICdz9hg5G27cdvbfeMIQJIK-RQ6B_5p1GkBrA>
#       to schedule time for learning
#     * Adopt one or two study habits
#       <https://eventing.coursera.-....CX1u-8vS96q-TLJPs9vjpWA7d2RbkMWJVo5f1wN_36A>
#       that make learning work for you
#
#
#
#
# Download our mobile app and learn on the go
#
#
# [iOS]
# <https://eventing.coursera.-....Br6KLerau1COqjviG_m0PtJuiZteUTXYMuFbY2lrn48>
# [Android]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3BsYXkuZ29vZ2xlLmNvbS9zdG9yZS9hcHBzL2RldGFpbHM_....Po9TKPwlCYQ2UvRfRX3ChyeVp5YxQTW69rLF67fgJsc>
#
#
#
#
# Connect with Coursera
# [FB]
# <https://eventing.coursera.....3JTAb6ob-zpEUr32Q8v8y1iN76v2tNVy_C0B1z-uSE8>
# [Twitter]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3R3aXR0ZXIuY29tL2NvdXJzZXJhP3V0bV9tZWRpdW09ZW1haWwmdXRtX3NvdXJjZT1vdGhlciZ1dG1fY2FtcGFpZ249b3BlbmNvdXJzZS53ZWxjb21lLmRhdGEtc2NpZW5jZS1tZXRob2RvbG9neS5-....FursrP5nnOW7KznS0QiTjxri7dWZIgbXoamXfOW_zEw>
# [Linkedin]
# <https://eventing.coursera.....BGxiqymyqNB-iNaeEwUTJW38Hv6ZBc0F2Ybk_-pwyCM>
#
#
#
#
# Help
# <https://eventing.coursera.....KyXp4SsMZcRINERztUdftkEWWmkUQGZPO2tVtOg9M4s>
# |Coursera for Business
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvYnVzaW5lc3MvP3V0bV9tZWRpdW09ZW1haWwmdXRtX3NvdXJjZT1vdGhlciZ1dG1fY2FtcGFpZ249b3BlbmNvdXJzZS53ZWxjb21lLmRhdGEtc2NpZW5jZS1tZXRob2RvbG9neS5-....K1I4ntWTn5h6dPwXvaLBppdlfnHcE5sUZ2T8uYTyyJ4>
# |Email Settings
# <https://eventing.coursera.....Z4AtkttDnRbBq5I4WoBIm2iuRtC1HhFM8jsoACMzN3Q>
# |Unsubscribe
# <https://eventing.coursera.....G4sJI8Xr7e22n_s_5jn24OTFoSscREv0k3VYFh93iy8>
#
#
#
#
# Copyright © 2023, Coursera Inc. | 381 E. Evelyn Ave, Mountain View, CA
# 94041 USA
# --------------------
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 578
# --------------------
# Get started with your first supplement
# --------------------
# Coursera
# --------------------
# no-reply@t.mail.coursera.org
# --------------------
# Trinh LeNhat
# --------------------
# trinhlnde170294@fpt.edu.vn
# --------------------
# 2023-11-03 02:28:37
# --------------------
# [coursera logo]
#
#
# You're on your way to new skills
#
#
# Hi Trinh Le Nhat,
#
# Welcome to What is Data Science? . Start learning with your first reading,
# which only takes 10 minutes. You're on your way to new skills!
#
# What is Data Science?
# Reading • 10 min
# <https://eventing.coursera.....M3LEl9aknPmR18NM7I5Wb91QOloDx1PJn3bRUmMKu5s>
# Go to Reading
# <https://eventing.coursera.....M3LEl9aknPmR18NM7I5Wb91QOloDx1PJn3bRUmMKu5s>
# Happy Learning,
# Coursera
#
# Looking for other tips to boost learning success?
#     * Download our mobile app
#       <https://eventing.coursera.....WbnHRfbgmEL-l7Cmjoi8G0vNE3nk-njOEKpLD0g4lmk>
#       to keep making progress anywhere
#     * Use the calendar feature
#       <https://eventing.coursera.....Yz7wxQMxfvVGnuEzDPVqFnH8aaPOwg5bkgFVMuyy7AI>
#       to schedule time for learning
#     * Adopt one or two study habits
#       <https://eventing.coursera.....34a0dYTSe5a1hOw5ccT6pTBitWjzXmA1zHRJbftH0Vo>
#       that make learning work for you
#
#
#
#
# Download our mobile app and learn on the go
#
#
# [iOS]
# <https://eventing.coursera.....SRNRSbIjQM08sPEQzJH3ijwa-XOsnac6ilc6JU-CZJk>
# [Android]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3BsYXkuZ29vZ2xlLmNvbS9zdG9yZS9hcHBzL2RldGFpbHM_aWQ9b3JnLmNvdXJzZXJhLmFuZHJvaWQmdXRtX21lZGl1bT1lbWFpbCZ1dG1fc291cmNlPW90aGVyJnV0bV9jYW1wYWlnbj1vcGVuY291cnNlLndlbGNvbWUud2hhdC1pcy1kYXRhc2NpZW5jZS5-....CkDkqIF9ZOgAvlJ8kHi5W4AKrRPkq0mDAL8YKSKdz30>
#
#
#
#
# Connect with Coursera
# [FB]
# <https://eventing.coursera.....xKnyZuDDsJ0oFkVBX575cyOGHZNSpXPKHIyDzJpZv64>
# [Twitter]
# <https://eventing.coursera.....rzDzm7aAdG35Dt29lcIn0PO5EUops3ax62ptZCkZnfw>
# [Linkedin]
# <https://eventing.coursera.....8GROndLeSso6kIQuYoE2YHjGBwG0wc5-POg6V67ukas>
#
#
#
#
# Help
# <https://eventing.coursera....._bak5lKckem3AepyS4CfUo7lXA2reTkNeoQvPHIhXcA>
# |Coursera for Business
# <https://eventing.coursera.....iV9FShJokmmARWNKhskVdxWa4LMWSwUTb3poi0W6dzk>
# |Email Settings
# <https://eventing.coursera.....3dxIBHOp9CMHHUO6hyL1ARP2K2uCnlw1Uq9dRzLwkw0>
# |Unsubscribe
# <https://eventing.coursera.....e8U8ExC5uj6nXT6pcjj9Vi8_HtNMovViBCw8DY3K4Cw>
#
#
#
#
# Copyright © 2023, Coursera Inc. | 381 E. Evelyn Ave, Mountain View, CA
# 94041 USA
# --------------------
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 344
# --------------------
# Get started with your first  reading
# --------------------
# Coursera
# --------------------
# no-reply@t.mail.coursera.org
# --------------------
# Trinh LeNhat
# --------------------
# trinhlnde170294@fpt.edu.vn
# --------------------
# 2024-03-20 17:59:39
# --------------------
# [coursera logo]
#
#
# You're on your way to new skills
#
#
# Hi Trinh Le Nhat,
#
# Welcome to Engineering Practices for Building Quality Software. Start
# learning with your first reading, which only takes 5 minutes. You're on
# your way to new skills!
#
# What is Quality Software?
# Reading • 5 min
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvbGVhcm4vZW5naW5lZXJpbmctcHJhY3RpY2VzLXNlY3VyZS1zb2Z0d2FyZS1xdWFsaXR5L2l0ZW0vdEp5QzI_....odFkTkAK2gGygAxF_Hu-b9Z_76kK1n15-6C-sUOWk54>
# Go to Reading
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3d3dy5jb3Vyc2VyYS5vcmcvbGVhcm4vZW5naW5lZXJpbmctcHJhY3RpY2VzLXNlY3VyZS1zb2Z0d2FyZS1xdWFsaXR5L2l0ZW0vdEp5QzI_....odFkTkAK2gGygAxF_Hu-b9Z_76kK1n15-6C-sUOWk54>
# Happy Learning,
# Coursera
#
# Looking for other tips to boost learning success?
#     * Download our mobile app
#       <https://eventing.coursera.-....kXSC-hrPbRWX0jL-zZFt_nUa806BWQ6rt25cVfh2J9M>
#       to keep making progress anywhere
#     * Use the calendar feature
#       <https://eventing.coursera.....XVO59Snur1VL1ZuLU4sP2UMY6N3KTNWbYlHGx16UIds>
#       to schedule time for learning
#     * Adopt one or two study habits
#       <https://eventing.coursera.-....q3nGpfE3hKN2EcwxEjXtqeJpoeJxWHhkwfUCh-XyaeA>
#       that make learning work for you
#
#
#
#
# Download our mobile app and learn on the go
#
#
# [iOS]
# <https://eventing.coursera.-....OMC7alRzAiz1XxLqs_SLtoBfwvv9RA8tZdDLW9Jh-zY>
# [Android]
# <https://eventing.coursera.org/redirectSigned/eyJrZXkiOiJlbWFpbC5saW5rLm9wZW4iLCJ2YWx1ZSI6eyJ1cmwiOiJodHRwczovL3BsYXkuZ29vZ2xlLmNvbS9zdG9yZS9hcHBzL2RldGFpbHM_....GXnNp7HPdrtUa6zUUHvlyfueztgG2bxLBwHrA5PHryA>
#
#
#
#
# Connect with Coursera
# [FB]
# <https://eventing.coursera.....Wcfawy-JJtm1h3gijAXxCXgqyntqqe7sGDX0b1TRCR4>
# [Twitter]
# <https://eventing.coursera.-....-obz9RVHcCiHoqirtzrSBVVW8r7f7oeDaa7E4aJZf_k>
# [Linkedin]
# <https://eventing.coursera.....GN_Cyw2CnetU_W-Kx9oxMw27CSCZjh3A3Qnxisx1oig>
#
#
#
#
# Help
# <https://eventing.coursera.....vTP51NtrGfq-jgFYcDlPK_YsV5JWMnYvaF4wljd7yAM>
# |Coursera for Business
# <https://eventing.coursera.-....kV6ykY0DO43tawQMNn6-n_liDOICfxpR-Vipekjiu3A>
# |Email Settings
# <https://eventing.coursera.....HLrB2KNqvRSsk2wSwenGvy5wYfzLFZmllUsad8iHN9k>
# |Unsubscribe
# <https://eventing.coursera....._fIyMR3TrjZ0_8IiAL5u6Pkx00t8AK69pHSMR5z_LiQ>
#
#
#
#
# Copyright © 2024, Coursera Inc. | 381 E. Evelyn Ave, Mountain View, CA
# 94041 USA
# --------------------
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
